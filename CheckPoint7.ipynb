# %%
import pandas as pd
import numpy as np
import math as mt 

exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes'],
'labels' : ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']}

#Creation of DataFrame
df = pd.DataFrame(exam_data)

#Index Setting 
df = df.set_index('labels')

#1
print(df.head(3))

#2
df = df.loc[df['score'] >= 0]

#3
ext = df[['name','score']]

#4
df2 = pd.DataFrame({'name' : ['Suresh'], 'score': [15.5], 'attempts': [1], 'qualify': ['yes'],'labels':['k']})
df2 = df2.set_index('labels')
df = pd.concat([df,df2])

#5
df = df.drop(labels='attempts',axis=1)

#6
it = list(df['score'])
add = [1 if i >10 else 0 for i in it]
df.insert(3, 'success', add, allow_duplicates=True)

#7
df.to_csv (r'C:\Users\onsou\OneDrive\Bureau\My_Data.csv', header=True)
# Out:
#              name  score  attempts qualify
# labels
# a       Anastasia   12.5         1     yes
# b            Dima    9.0         3      no
# c       Katherine   16.5         2     yes
